# %%
# Endereço para plotar legal.
# https://matplotlib.org/stable/plot_types/index.html
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# plt.style.use('Solarize_Light2')
x = np.linspace(0, 5, 100)
y = x ** 2
plt.plot(x, y)
plt.show()

# %%
# Várias configurações básicas.
plt.plot(x, y, 'r') # Mudar a cor da parada.
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.title('Título Isano')
plt.show()

# %% [markdown]
# ## Subplots

# %%
# Subplots
plt.subplot(1, 2, 1)
plt.plot(x, y, 'r')

plt.subplot(1, 2, 2)
plt.plot(x, y, 'g')

plt.show()

# %%
fig = plt.figure()

# Os dois primeiros números são referentes ao eixo a partir do qual tudo começa.
# Os dois números subsequentes são a escala de crescimento.
axis1 = fig.add_axes([0,0,0.5,0.5])     # Começa em x=0.0, y=0.0, e cresce numa escala de 0.5 para ambas as direções.
axis2 = fig.add_axes([0.6,0,0.5,0.5])   # Começa em x=0.6, y=0.0, e cresce numa escala de 0.5 para ambas as direções.

axis1.plot(x, y/2 + 2)
axis2.plot(x, y*np.sin(2*np.pi))

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,2))

axes[0].plot(x, y)
axes[0].set_title('First Plot', color="red")
axes[1].plot(2*y, x)
axes[1].set_title('Second Plot', color="red")
plt.tight_layout()

# %% [markdown]
# ## Logaritmo

# %%
import matplotlib.pyplot as plt

x = list(range(0,1000))
y = [ element ** 2 for element in x]

plt.plot(x, y)
plt.show()

# %%
import numpy as np

x = np.arange(0, 1000)
y = x ** 2

plt.plot(x, y)
plt.show()

plt.xscale('log')
plt.plot(x, y)
plt.show()

# %%
x = list(range(0, 1000))
y =  [1] * 1000
print(x.__len__())
print(y.__len__())
plt.plot(x, y)
# Out:
# 1000
# 1000

# %%
yy = [np.cos(number/100) for number in x]

# %%
plt.yticks([0, 0.25, 0.50, 0.75, 1], ['0', '1/4', '1/2', '3/4', '1'])
plt.plot(x, yy)
